# %% [markdown]
# <a href="https://colab.research.google.com/github/VictorOmondi1997/Exploring_gapminder_dataset/blob/master/Tidyverse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploring the gapminder

# %%
install.packages("gapminder")
library(gapminder)
library(dplyr)
library(ggplot2)
gapminder
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#      country     continent year lifeExp pop      gdpPercap
# 1    Afghanistan Asia      1952 28.801   8425333  779.4453
# 2    Afghanistan Asia      1957 30.332   9240934  820.8530
# 3    Afghanistan Asia      1962 31.997  10267083  853.1007
# 4    Afghanistan Asia      1967 34.020  11537966  836.1971
# 5    Afghanistan Asia      1972 36.088  13079460  739.9811
# 6    Afghanistan Asia      1977 38.438  14880372  786.1134
# 7    Afghanistan Asia      1982 39.854  12881816  978.0114
# 8    Afghanistan Asia      1987 40.822  13867957  852.3959
# 9    Afghanistan Asia      1992 41.674  16317921  649.3414
# 10   Afghanistan Asia      1997 41.763  22227415  635.3414
# 11   Afghanistan Asia      2002 42.129  25268405  726.7341
# 12   Afghanistan Asia      2007 43.828  31889923  974.5803
# 13   Albania     Europe    1952 55.230   1282697 1601.0561
# ...

# %%
print(gapminder)
# Out:
# # A tibble: 1,704 x 6
#    country     continent  year lifeExp      pop gdpPercap
#    <fct>       <fct>     <int>   <dbl>    <int>     <dbl>
#  1 Afghanistan Asia       1952    28.8  8425333      779.
#  2 Afghanistan Asia       1957    30.3  9240934      821.
#  3 Afghanistan Asia       1962    32.0 10267083      853.
#  4 Afghanistan Asia       1967    34.0 11537966      836.
#  5 Afghanistan Asia       1972    36.1 13079460      740.
#  6 Afghanistan Asia       1977    38.4 14880372      786.
#  7 Afghanistan Asia       1982    39.9 12881816      978.
#  8 Afghanistan Asia       1987    40.8 13867957      852.
#  9 Afghanistan Asia       1992    41.7 16317921      649.
# 10 Afghanistan Asia       1997    41.8 22227415      635.
# # … with 1,694 more rows

# %% [markdown]
# # Filtering

# %%
print(gapminder %>% filter(year==1957))
# Out:
# # A tibble: 142 x 6
#    country     continent  year lifeExp      pop gdpPercap
#    <fct>       <fct>     <int>   <dbl>    <int>     <dbl>
#  1 Afghanistan Asia       1957    30.3  9240934      821.
#  2 Albania     Europe     1957    59.3  1476505     1942.
#  3 Algeria     Africa     1957    45.7 10270856     3014.
#  4 Angola      Africa     1957    32.0  4561361     3828.
#  5 Argentina   Americas   1957    64.4 19610538     6857.
#  6 Australia   Oceania    1957    70.3  9712569    10950.
#  7 Austria     Europe     1957    67.5  6965860     8843.
#  8 Bahrain     Asia       1957    53.8   138655    11636.
#  9 Bangladesh  Asia       1957    39.3 51365468      662.
# 10 Belgium     Europe     1957    69.2  8989111     9715.
# # … with 132 more rows

# %% [markdown]
# # Filter for China in 2002

# %%
gapminder %>% filter(country=='China', year==2002)
# Out:
#   country continent year lifeExp pop        gdpPercap
# 1 China   Asia      2002 72.028  1280400000 3119.281

# %% [markdown]
# # Sorting
#
# ## Sort in ascending order of lifeExp

# %%
gapminder %>% 
  arrange(lifeExp)
# Out:
#      country           continent year lifeExp pop       gdpPercap
# 1    Rwanda            Africa    1992 23.599   7290203   737.0686
# 2    Afghanistan       Asia      1952 28.801   8425333   779.4453
# 3    Gambia            Africa    1952 30.000    284320   485.2307
# 4    Angola            Africa    1952 30.015   4232095  3520.6103
# 5    Sierra Leone      Africa    1952 30.331   2143249   879.7877
# 6    Afghanistan       Asia      1957 30.332   9240934   820.8530
# 7    Cambodia          Asia      1977 31.220   6978607   524.9722
# 8    Mozambique        Africa    1952 31.286   6446316   468.5260
# 9    Sierra Leone      Africa    1957 31.570   2295678  1004.4844
# 10   Burkina Faso      Africa    1952 31.975   4469979   543.2552
# 11   Afghanistan       Asia      1962 31.997  10267083   853.1007
# 12   Angola            Africa    1957 31.999   4561361  3827.9405
# 13   Gambia            Africa    1957 32.065    323150   520.9267
# ...

# %%
gapminder %>% 
  arrange(desc(lifeExp))
# Out:
#      country           continent year lifeExp pop       gdpPercap
# 1    Japan             Asia      2007 82.603  127467972 31656.07
# 2    Hong Kong, China  Asia      2007 82.208    6980412 39724.98
# 3    Japan             Asia      2002 82.000  127065841 28604.59
# 4    Iceland           Europe    2007 81.757     301931 36180.79
# 5    Switzerland       Europe    2007 81.701    7554661 37506.42
# 6    Hong Kong, China  Asia      2002 81.495    6762476 30209.02
# 7    Australia         Oceania   2007 81.235   20434176 34435.37
# 8    Spain             Europe    2007 80.941   40448191 28821.06
# 9    Sweden            Europe    2007 80.884    9031088 33859.75
# 10   Israel            Asia      2007 80.745    6426679 25523.28
# 11   Japan             Asia      1997 80.690  125956499 28816.58
# 12   France            Europe    2007 80.657   61083916 30470.02
# 13   Canada            Americas  2007 80.653   33390141 36319.24
# ...

# %% [markdown]
# # Filter for the year 1957, then arrange in descending order of population

# %%
gapminder %>%
  filter(year==1957) %>%
    arrange(desc(pop))
# Out:
#     country               continent year lifeExp  pop       gdpPercap
# 1   China                 Asia      1957 50.54896 637408000   575.9870
# 2   India                 Asia      1957 40.24900 409000000   590.0620
# 3   United States         Americas  1957 69.49000 171984000 14847.1271
# 4   Japan                 Asia      1957 65.50000  91563009  4317.6944
# 5   Indonesia             Asia      1957 39.91800  90124000   858.9003
# 6   Germany               Europe    1957 69.10000  71019069 10187.8267
# 7   Brazil                Americas  1957 53.28500  65551171  2487.3660
# 8   United Kingdom        Europe    1957 70.42000  51430000 11283.1779
# 9   Bangladesh            Asia      1957 39.34800  51365468   661.6375
# 10  Italy                 Europe    1957 67.81000  49182000  6248.6562
# 11  Pakistan              Asia      1957 45.55700  46679944   747.0835
# 12  France                Europe    1957 68.93000  44310863  8662.8349
# ...

# %% [markdown]
# # Mutating lifeExp to lifeExpMonths

# %%
gapminder %>%
  mutate(lifeExpMonths=lifeExp*12)
# Out:
#      country     continent year lifeExp pop      gdpPercap lifeExpMonths
# 1    Afghanistan Asia      1952 28.801   8425333  779.4453 345.612
# 2    Afghanistan Asia      1957 30.332   9240934  820.8530 363.984
# 3    Afghanistan Asia      1962 31.997  10267083  853.1007 383.964
# 4    Afghanistan Asia      1967 34.020  11537966  836.1971 408.240
# 5    Afghanistan Asia      1972 36.088  13079460  739.9811 433.056
# 6    Afghanistan Asia      1977 38.438  14880372  786.1134 461.256
# 7    Afghanistan Asia      1982 39.854  12881816  978.0114 478.248
# 8    Afghanistan Asia      1987 40.822  13867957  852.3959 489.864
# 9    Afghanistan Asia      1992 41.674  16317921  649.3414 500.088
# 10   Afghanistan Asia      1997 41.763  22227415  635.3414 501.156
# 11   Afghanistan Asia      2002 42.129  25268405  726.7341 505.548
# 12   Afghanistan Asia      2007 43.828  31889923  974.5803 525.936
# 13   Albania     Europe    1952 55.230   1282697 1601.0561 662.760
# ...

# %%
gapminder %>%
  filter(year==2007) %>%
    mutate(lifeExpMonths=lifeExp*12) %>%
      arrange(desc(lifeExpMonths))
# Out:
#     country                  continent year lifeExp pop       gdpPercap
# 1   Japan                    Asia      2007 82.603  127467972 31656.068
# 2   Hong Kong, China         Asia      2007 82.208    6980412 39724.979
# 3   Iceland                  Europe    2007 81.757     301931 36180.789
# 4   Switzerland              Europe    2007 81.701    7554661 37506.419
# 5   Australia                Oceania   2007 81.235   20434176 34435.367
# 6   Spain                    Europe    2007 80.941   40448191 28821.064
# 7   Sweden                   Europe    2007 80.884    9031088 33859.748
# 8   Israel                   Asia      2007 80.745    6426679 25523.277
# 9   France                   Europe    2007 80.657   61083916 30470.017
# 10  Canada                   Americas  2007 80.653   33390141 36319.235
# 11  Italy                    Europe    2007 80.546   58147733 28569.720
# 12  New Zealand              Oceania   2007 80.204    4115771 25185.009
# ...

# %% [markdown]
# # Visualizing a subset of the gapminder data from the year 1952

# %%
gapminder_1952 = gapminder %>% filter(year==1952)
gapminder_1952
# Out:
#     country                  continent year lifeExp pop       gdpPercap
# 1   Afghanistan              Asia      1952 28.801    8425333   779.4453
# 2   Albania                  Europe    1952 55.230    1282697  1601.0561
# 3   Algeria                  Africa    1952 43.077    9279525  2449.0082
# 4   Angola                   Africa    1952 30.015    4232095  3520.6103
# 5   Argentina                Americas  1952 62.485   17876956  5911.3151
# 6   Australia                Oceania   1952 69.120    8691212 10039.5956
# 7   Austria                  Europe    1952 66.800    6927772  6137.0765
# 8   Bahrain                  Asia      1952 50.939     120447  9867.0848
# 9   Bangladesh               Asia      1952 37.484   46886859   684.2442
# 10  Belgium                  Europe    1952 68.000    8730405  8343.1051
# 11  Benin                    Africa    1952 38.223    1738315  1062.7522
# 12  Bolivia                  Americas  1952 40.414    2883315  2677.3263
# ...

# %% [markdown]
# # Comparing GDP per Capita and Life Expectacy

# %%
ggplot(gapminder_1952, 
  aes(x=gdpPercap, y=lifeExp))+
geom_point()
# Out:
# plot without title

# %% [markdown]
# # Comparing population and GDP per capita

# %%
ggplot(gapminder_1952, 
  aes(x=pop, y=gdpPercap))+
geom_point()+scale_x_log10()+scale_y_log10()
# Out:
# plot without title

# %% [markdown]
# # Comparing population and life expectancy

# %%
ggplot(gapminder_1952, 
  aes(x=pop, y=lifeExp, color=continent, size=gdpPercap))+
  geom_point()+
  scale_x_log10()
# Out:
# plot without title

# %%
ggplot(gapminder_1952, aes(x=pop, y=lifeExp))+geom_point()+scale_x_log10()+facet_wrap(~continent)
# Out:
# plot without title

# %% [markdown]
# #comparing gdpPercap and lifeExp, with color representing continent and size representing population, faceted by year

# %%
ggplot(gapminder, aes(x=gdpPercap, y=lifeExp, color=continent, size=pop))+geom_point()+scale_x_log10()+facet_wrap(~year)
# Out:
# plot without title

# %% [markdown]
# # the median life expectancy

# %%
gapminder %>%
  summarize(medianLifeExp=median(lifeExp))
# Out:
#   medianLifeExp
# 1 60.7125

# %%
gapminder %>%
  filter(year==1957) %>%
    summarize(medianLifeExp=median(lifeExp), maxGdpPerCap=max(gdpPercap))
# Out:
#   medianLifeExp maxGdpPerCap
# 1 48.3605       113523.1

# %% [markdown]
# # median life expectancy and maximum GDP per capita in each year

# %%
by_year = gapminder %>%
  group_by(year) %>%
    summarize(medianLifeExp=median(lifeExp), maxGdpPercap=max(gdpPercap))

# %%
by_year
# Out:
#    year medianLifeExp maxGdpPercap
# 1  1952 45.1355       108382.35
# 2  1957 48.3605       113523.13
# 3  1962 50.8810        95458.11
# 4  1967 53.8250        80894.88
# 5  1972 56.5300       109347.87
# 6  1977 59.6720        59265.48
# 7  1982 62.4415        33693.18
# 8  1987 65.8340        31540.97
# 9  1992 67.7030        34932.92
# 10 1997 69.3940        41283.16
# 11 2002 70.8255        44683.98
# 12 2007 71.9355        49357.19

# %%
ggplot(by_year, aes(x=year, y=medianLifeExp))+geom_line()+expand_limits(y=0)
# Out:
# plot without title

# %% [markdown]
# It looks like median life expectancy across countries is increasing over time.

# %% [markdown]
# notice that median life expectancy across countries is generally going up over time, but maximum GDP per capita is not.

# %% [markdown]
# # median life expectancy and maximum GDP per capita in each continent in 1957

# %%
gapminder %>%
  filter(year==1957) %>%
    group_by(continent) %>%
      summarize(medianLifeExp=median(lifeExp), maxGdpPercap=max(gdpPercap)) %>%
        arrange(desc(medianLifeExp))
# Out:
#   continent medianLifeExp maxGdpPercap
# 1 Oceania   70.2950        12247.395
# 2 Europe    67.6500        17909.490
# 3 Americas  56.0740        14847.127
# 4 Asia      48.2840       113523.133
# 5 Africa    40.5925         5487.104

# %% [markdown]
# Oceania continent had the highest median life expectancy in 1957
#
# # median life expectancy and maximum GDP per capita in each continent/year combination

# %%
gapminder %>%
  group_by(continent, year) %>%
    summarize(medianLifeExp=median(lifeExp), maxGdpPercap=max(gdpPercap))
# Out:
#    continent year medianLifeExp maxGdpPercap
# 1  Africa    1952 38.8330         4725.296
# 2  Africa    1957 40.5925         5487.104
# 3  Africa    1962 42.6305         6757.031
# 4  Africa    1967 44.6985        18772.752
# 5  Africa    1972 47.0315        21011.497
# 6  Africa    1977 49.2725        21951.212
# 7  Africa    1982 50.7560        17364.275
# 8  Africa    1987 51.6395        11864.408
# 9  Africa    1992 52.4290        13522.158
# 10 Africa    1997 52.7590        14722.842
# 11 Africa    2002 51.2355        12521.714
# 12 Africa    2007 52.9265        13206.485
# 13 Americas  1952 54.7450        13990.482
# 14 Americas  1957 56.0740        14847.127
# 15 Americas  1962 58.2990        16173.146
# 16 Americas  1967 60.5230        19530.366
# 17 Americas  1972 63.4410        21806.036
# 18 Americas  1977 66.3530        24072.632
# 19 Americas  1982 67.4050        25009.559
# 20 Americas  1987 69.4980        29884.350
# 21 Americas  1992 69.8620        32003.932
# ...

# %% [markdown]
# # Visualizing median GDP per capita per continent over time

# %%
by_year_continent = gapminder %>% group_by(year, continent) %>% summarize(medianGdpPercap=median(gdpPercap))
by_year_continent
# Out:
#    year continent medianGdpPercap
# 1  1952 Africa      987.0256
# 2  1952 Americas   3048.3029
# 3  1952 Asia       1206.9479
# 4  1952 Europe     5142.4697
# 5  1952 Oceania   10298.0857
# 6  1957 Africa     1024.0230
# 7  1957 Americas   3780.5467
# 8  1957 Asia       1547.9448
# 9  1957 Europe     6066.7215
# 10 1957 Oceania   11598.5225
# 11 1962 Africa     1133.7837
# 12 1962 Americas   4086.1141
# 13 1962 Asia       1649.5522
# 14 1962 Europe     7515.7337
# 15 1962 Oceania   12696.4524
# 16 1967 Africa     1210.3764
# 17 1967 Americas   4643.3935
# 18 1967 Asia       2029.2281
# 19 1967 Europe     9366.0670
# 20 1967 Oceania   14495.0218
# 21 1972 Africa     1443.3725
# 22 1972 Americas   5305.4453
# 23 1972 Asia       2571.4230
# 24 1972 Europe    12326.3800
# 25 1972 Oceania   16417.3334
# 26 1977 Africa     1399.6388
# 27 1977 Americas   6281.2909
# 28 1977 Asia       3195.4846
# 29 1977 Europe    14225.7545
# 30 1977 Oceania   17283.9576
# 31 1982 Africa     1323.7283
# ...

# %%
ggplot(by_year_continent, aes(x=year, y=medianGdpPercap, color=continent))+geom_line()+expand_limits(y=0)
# Out:
# plot without title

# %% [markdown]
# # Comparing median life expectancy and median GDP per continent in 2007

# %%
by_continent_2007 = gapminder %>% filter(year==2007) %>% group_by(continent) %>% summarize(medianLifeExp=median(lifeExp), medianGdpPercap=median(gdpPercap))
by_continent_2007
# Out:
#   continent medianLifeExp medianGdpPercap
# 1 Africa    52.9265        1452.267
# 2 Americas  72.8990        8948.103
# 3 Asia      72.3960        4471.062
# 4 Europe    78.6085       28054.066
# 5 Oceania   80.7195       29810.188

# %%
ggplot(by_continent_2007, aes(x=medianGdpPercap, y=medianLifeExp, color=continent, size=medianGdpPercap))+geom_point()+expand_limits(y=0)
# Out:
# plot without title

# %% [markdown]
# # Visualizing median GDP per capita by continent in 2007

# %%
ggplot(by_continent_2007, aes(x=continent, y=medianGdpPercap))+geom_col()
# Out:
# plot without title

# %% [markdown]
# # Visualizing median GDP per capita over time

# %%
by_year = gapminder %>%
  group_by(year) %>%
    summarize(medianGdpPercap=median(gdpPercap))
ggplot(by_year, aes(x=year, y=medianGdpPercap))+geom_line()+expand_limits(y=0)
# Out:
# plot without title

# %% [markdown]
# Looks like median GDP per capita across countries has gone up over time.

# %% [markdown]
# # medianGdp by continent in 1952

# %%
by_continent = gapminder %>% filter(year==1952) %>% group_by(continent) %>% summarize( medianGdpPercap=median(gdpPercap))
ggplot(by_continent, aes(x=continent, y=medianGdpPercap))+geom_col()
# Out:
# plot without title

# %% [markdown]
# # Visualizing GDP per capita by country in Oceania in 1952

# %%
oceania_1952 = gapminder %>% filter(year==1952, continent=='Oceania')
ggplot(oceania_1952, aes(x=country, y=gdpPercap))+geom_col()
# Out:
# plot without title

# %% [markdown]
# Looks like the GDP per capita of these two countries was similar in 1952.

# %% [markdown]
# # Visualizing population in the year 1952

# %%
gapminder_1952 <- gapminder %>%
  filter(year == 1952)
ggplot(gapminder_1952, aes(x=pop))+geom_histogram()+scale_x_log10()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# # Comparing GDP per capita across continents in 1952

# %%
ggplot(gapminder_1952, aes(x=continent, y=gdpPercap))+geom_boxplot()+scale_y_log10()+ggtitle("Comparing GDP per capita across continents")
# Out:
# plot without title
